# %%
import pickle
filename = "finalized_Multiplelinear.sav"
pickle.dump(regressor , open(filename,"wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pickle
#       2 filename = "finalized_Multiplelinear.sav"
# ----> 3 pickle.dump(regressor , open(filename,"wb"))
#
# NameError: name 'regressor' is not defined

# %%
loadmodel= pickle.load(open(filename,"rb"))
result = loadmodel.predict([[5567,1567,4567,1,0]])
# Out:
# C:\Users\Divya\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[47458.12698447]])
